# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/RNX/blob/main/pytorch-3D-plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://machinelearningmastery.com/manipulating-tensors-in-pytorch/?utm_source=drip&utm_medium=email&utm_campaign=Manipulating+tensors+in+PyTorch&utm_content=Manipulating+tensors+in+PyTorch

# %%
import matplotlib.pyplot as plt
import torch

# create tensors
x = torch.linspace(-1, 1, 100)
y = torch.linspace(-2, 2, 100)
# create the surface
xx, yy = torch.meshgrid(x, y, indexing="xy")  # xy-indexing is matching numpy
z = torch.sqrt(1 - xx**2 - (yy/2)**2)
print(xx)

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection="3d")
ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.set_zlim([0, 2])
ax.plot_surface(xx, yy, z, cmap="cividis")
ax.view_init(45, 35)
plt.show()
# Out:
# tensor([[-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000],
#         [-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000],
#         [-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000],
#         ...,
#         [-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000],
#         [-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000],
#         [-1.0000, -0.9798, -0.9596,  ...,  0.9596,  0.9798,  1.0000]])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-eaf08bccfb67> in <module>
#      15 ax.set_ylim([-2, 2])
#      16 ax.set_zlim([0, 2])
# ---> 17 ax.plot_surface(xx, yy, z, cmap="cividis")
#      18 ax.view_init(45, 35)
#      19 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
# ...
